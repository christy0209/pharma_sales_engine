# %%
import warnings
warnings.filterwarnings("ignore")
from utils.utils import LLM_GROQ,generate_df
import json
import pandas as pd
from IPython.display import display

# %% [markdown]
# ## Alfex 180mg Tablet

# %%
medicine_name = "Alfex 180mg Tablet"
op = LLM_GROQ(medicine_name)
df = generate_df(op)
display(df)
# Out:
#                    Medicine                        Manufactured By  \
# 0   Allergifex 180mg Tablet                 Oswald Pharmaceuticals
# 1       Alfexa 180mg Tablet               Elkos Healthcare Pvt Ltd
# 2       Biofex 180mg Tablet                    Biosys Medisciences
# 3       Fexolife 180 Tablet         Dr. Johns Laboratories Pvt Ltd
# 4          Fegra 180 Tablet                    Comed Chemicals Ltd
# 5      Fexonet 180mg Tablet                          Rosnet Pharma
# 6     Fexonice 180mg Tablet           Fidalgo Laboratories Pvt Ltd
# 7      Fextral 180mg Tablet  Indchemie Health Specialities Pvt Ltd
# 8      Fexonto 180mg Tablet          Prevento Remedies Corporation
# 9      Fexoril 180mg Tablet                    Trillest Healthcare
# 10      Fekast 180mg Tablet            Verrmont Healthcare Pvt Ltd
# 11     Symfine 180mg Tablet        Kinesis Pharmaceuticals Pvt Ltd
# 12    Wexodine 180mg Tablet                       Zee Laboratories
# ...

# %% [markdown]
# ## Megaclav Dry Syrup

# %%
medicine_name = "Megaclav Dry Syrup"
op = LLM_GROQ(medicine_name)
df = generate_df(op)
df
# Out:
#                      Medicine              Manufactured By  \
# 0  Ampoxin-CV Forte Dry Syrup  Torrent Pharmaceuticals Ltd
# 1         Amoclave  DS  Syrup    Marc Laboratories Pvt Ltd
# 2     Axonic CV Duo Dry Syrup         Kyna Pharmaceuticals
# 3       Cavmox Duos Dry Syrup       Leeford Healthcare Ltd
#
#          Active Ingredients  Uses and Indications Dosage Forms  \
# 0  Amoxicillin, Clavulanate  Bacterial infections    Dry Syrup
# 1  Amoxicillin, Clavulanate  Bacterial infections        Syrup
# 2  Amoxicillin, Clavulanate  Bacterial infections    Dry Syrup
# 3  Amoxicillin, Clavulanate  Bacterial infections    Dry Syrup
#
#                      Strength and Composition  \
# 0  Amoxicillin (200mg) + Clavulanate (28.5mg)
# 1  Amoxicillin (200mg) + Clavulanate (28.5mg)
# 2  Amoxicillin (200mg) + Clavulanate (28.5mg)
# 3  Amoxicillin (200mg) + Clavulanate (28.5mg)
#
#   Side Effects & Contraindications    Prescription Use Alternative Uses
# ...

# %% [markdown]
# ## Sucral Ano Cream

# %%
medicine_name = "Sucral Ano Cream"
op = LLM_GROQ(medicine_name)
df = generate_df(op)
df
# Out:
#                  Medicine                    Manufactured By Similarity  \
# 0  Elfate-LM Rectal Cream  Estrellas Life Sciences Pvt. Ltd.        NaN
# 1        Sufrate LA Cream               Eskag Pharma Pvt Ltd        NaN
# 2            Surect Cream      Nemus Pharmaceuticals Pvt Ltd        NaN
#
#   Active Ingredients Uses and Indications  Dosage Forms  \
# 0          Different            Different  Rectal Cream
# 1          Different            Different         Cream
# 2          Different            Different         Cream
#
#   Strength and Composition Side Effects & Contraindications  \
# 0                Different            Rectal Bleeding, Pain
# 1                Different             Skin Rashes, Itching
# 2                Different             Skin Rashes, Itching
#
#              Prescription Use Alternative Uses
# 0  Rectal administration only              Yes
# 1         Topical Application              Yes
# 2         Topical Application              Yes

# %% [markdown]
# ## Fexert 180mg Tablet

# %%
medicine_name = "Fexert 180mg Tablet"
op = LLM_GROQ(medicine_name)
df = generate_df(op)
df
# Out:
#                    Medicine                        Manufactured By  \
# 0        Alfex 180mg Tablet           Zota Pharmaceuticals Pvt Ltd
# 1     Allerfex 180mg Tablet            Torrent Pharmaceuticals Ltd
# 2      Allegix 180mg Tablet              Intas Pharmaceuticals Ltd
# 3   Allergifex 180mg Tablet                 Oswald Pharmaceuticals
# 4       Biofex 180mg Tablet                    Biosys Medisciences
# 5       Finide 180mg Tablet  Indchemie Health Specialities Pvt Ltd
# 6      Fenofex 180mg Tablet                        Apco Pharma Ltd
# 7     Fexogail 180mg Tablet            Abigail Care Pharmaceutical
# 8       Fexopill 180 Tablet                    Zumentes Healthcare
# 9      Fextiva 180mg Tablet                     Solace Biotech Ltd
# 10     Fexoreg 180mg Tablet                Regulus Pharmaceuticals
# 11    Fexomedg 180mg Tablet                            Medg Pharma
# 12     Fexodek 180mg Tablet                            Auriga Labs
# ...

# %% [markdown]
# ## END
